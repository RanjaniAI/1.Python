# %%
class MultipleFunctions():
    def OddEven():        
        if((number%2)==0):
            Val="is Even number"
        else:
            Val="is Odd number"
        return Val
    def Elegible(age_val, Gender_val):
        if(Gender_val=="Female"):
            if(age_val>=21):
                Message="ELIGIBLE"
            else:
                Message="NOT ELIGIBLE"
        else:
            if(age_val>=25):
                Message="ELIGIBLE"
            else:
                Message="NOT ELIGIBLE"
        return Message

# %%
number=int(input("Enter a number:"))
Value=MultipleFunctions.OddEven()
print(number,Value)
# Out:
# Enter a number:26
# 26 is Even number

# %%
Gender=input("Your Gender:")
age=int(input("Your Age:"))
Marriage=MultipleFunctions.Elegible(age,Gender)
print(Marriage)
# Out:
# Your Gender:Female
# Your Age:25
# ELIGIBLE
