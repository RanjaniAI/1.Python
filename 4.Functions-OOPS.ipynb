# %%
list=[12,25,35,47,56,68]

# %%
def ageCalculator():
    for age in list:
        if(age<18):
            print("Childern")
        elif(age<35):
            print("Adult")
        elif(age<59):
            print("Citizen")
        else:
            print("Senior citizen")

# %%
ageCalculator()
# Out:
# Childern
# Adult
# Citizen
# Citizen
# Citizen
# Senior citizen

# %%
def AgeCalc():
        if(age<18):
            cate="Childern"
        elif(age<35):
            cate="Adult"
        elif(age<59):
            cate="Citizen"
        else:
            cate="Senior citizen"
        return cate

# %%
age=int(input("Enter the age:"))
value=AgeCalc()
print(value)
# Out:
# Enter the age:19
# Adult

# %%
def add(num1, num2):
    addition=num1+num2
    return addition

# %%
Addition_value=add(2,6)
print(Addition_value)
# Out:
# 8
